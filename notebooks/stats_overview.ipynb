# %%
import pandas as pd

# %%
df = pd.read_csv('../data/charting-m-stats-Overview.csv')

# %%
player_names = df['player']

# %%
player_names
# Out:
# 0            Jesper De Jong
# 1             Michael Zheng
# 2            Jesper De Jong
# 3             Michael Zheng
# 4            Jesper De Jong
#                 ...
# 56845            Luis Ayala
# 56846    Nicola Pietrangeli
# 56847            Luis Ayala
# 56848    Nicola Pietrangeli
# 56849            Luis Ayala
# Name: player, Length: 56850, dtype: str

# %%
player_name_roger_federer = df['player'] == 'Roger Federer'
